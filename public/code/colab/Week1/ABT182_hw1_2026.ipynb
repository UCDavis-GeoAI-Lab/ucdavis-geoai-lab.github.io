# %% [markdown]
# <font color="green"><h1> **Welcome to ABT/HYD 182**
#
#
#  ## **Lab 1**: Introduction to Colab for Python programming
#
# ### **Due Date: Jan 13 | 11:59 PM**
# ------------------------------------------------------------------------------

# %% [markdown]
# ## Academic Integrity Statement
#
# **This work was completed without the use of Generative AI tools (such as ChatGPT, Copilot, etc.).**
#
# By completing the information below, you certify that you have completed this assignment independently and without the assistance of generative AI tools. This tutorial is designed to help you learn Python programming fundamentals through hands-on practice.
#
# ---
#
# **Note:** If you did use a generative AI tool, you must clearly disclose this in your notebook, including which tool you used and how you used it (e.g., debugging, understanding error messages, or clarifying concepts). Failure to disclose the use of generative AI tools may be considered a violation of course academic integrity policies.

# %%
# Enter your information below
your_name = ""  # Replace with your full name
date = ""       # Replace with today's date (e.g., "January 7, 2026")

# Print your statement
print("Academic Integrity Statement")
print("=" * 50)
print(f"Name: {your_name}")
print(f"Date: {date}")
print("=" * 50)
print("I certify that this work was completed without the use of Generative AI tools.")

# %% [markdown]
# # Table of Contents
# >1. [Google Colab](#section1)
# >2. [Defining variables](#section2)
#
# >>>    2.1. [Exercise 1](#subsection2.1)
#
# >>>    2.2. [Exercise 2](#subsection2.2)
#
# >3. [Mathematical operation](#section3)
#
# >>>    3.1. [Excercise 3](#subsection3.1)
#
# >>>    3.2. [Excercise 4](#subsection3.2)
#
# >>>    3.3. [Excercise 5](#subsection3.3)
#
# >4. [How to submit the assignment?](#section4)
#
# >5. [Resources to learn Python](#section5)

# %% [markdown]
# <a name = "section1"></a>
# ## Google Colab
#
# - is an executable document to write, run, and share your code within Google Drive.
# - connects your notebook to a cloud-based (remote) instance.
# - **does NOT need any required Python setup on your machine.** It comes with the widely used python libraries and packages.
# - requires a Google account.
# - is FREE environment to develop Python scripts.
#
#
#   #### Google Colab Tutorials:
# >- [Get started with Google Colaboratory (video)](https://www.youtube.com/watch?v=inN8seMm7UI)
# >- [What is Google Colab: A Beginner’s Guide](https://bytexd.com/what-is-google-colab-a-beginner-guide/)
# >- [Google Colab Tutorial for Beginners | Get Started with Google Colab](https://www.youtube.com/watch?v=RLYoEyIHL6A)
# >- [Google Colab - Your First Colab Notebook](https://www.tutorialspoint.com/google_colab/your_first_colab_notebook.htm)
# >- [Python Tutorial With Google Colab](https://colab.research.google.com/github/cs231n/cs231n.github.io/blob/master/python-colab.ipynb#scrollTo=dzNng6vCL9eP)
# >- [Tutorial video - Google Colab](https://www.youtube.com/watch?v=KCCzo31Oo8U&feature=emb_logo)
#
# #### Google Colab Markdown:
# >- [Cheat-sheet_for_Google_Colab](https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Cheat_sheet_for_Google_Colab.ipynb)
# >- [Mastering Markdown](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax)
# >- [Markdown Guide](https://colab.research.google.com/notebooks/markdown_guide.ipynb)

# %% [markdown]
# <a name = "section2"></a>
# ## Defining variables

# %% [markdown]
# <a name = "subsection2.1"></a>
# **Excercise 1**
# : Working with Variables and Strings
#
# In this exercise, you will practice creating variables, using user input, and working with text (strings).
#
# ### Instructions
#
# 1. Define a variable called `firstName` and assign your **first name** to it.
#    You may use the Python built-in `input()` function to prompt the user to enter their first name.
#
# 2. Define a variable called `lastName` and assign your **last name** to it.
#    Similarly, use the `input()` function to prompt the user to enter their last name.
#
# 3. Combine `firstName` and `lastName` with a **space in between**, and assign the result to a new variable called `fullname`.
#
# 4. Print the variable `fullname` using the `print()` function.
#    You may print a full sentence, for example:
#    > Full name is John Doe
#
# ---
#
# ### Hint
# You can add a space between two strings using `" "` (quotation mark, space, another quotation mark).
#
# ---
#
# [Examples for input() function](https://www.w3schools.com/python/ref_func_input.asp)
#
# [Examples for print() function](https://www.w3schools.com/python/ref_func_print.asp)
#
# [Examples for using f-strings in Python](https://www.geeksforgeeks.org/formatted-string-literals-f-strings-python/)
#
# [Placeholders in python](https://matcha.fyi/python-placeholder/)

# %%
# write your code here

# %% [markdown]
# <a name="subsection2.2"></a>
#
# ## Exercise 2: Working with Strings and Printing
#
# In this exercise, you will create a new variable and practice printing a sentence using multiple variables.
#
# ### Instructions
#
# 1. Create a variable called `favorite_place` and assign your **favorite place to live** to it.
#    You may use the `input()` function to prompt the user to enter their favorite place.
#
# 2. Use the `print()` function to display a complete sentence that includes both variables.
#    For example:
#    > My name is John Doe, and my favorite place to live is New York.

# %%
# write your code here

# %% [markdown]
# <a name = "section3"></a>
# ## Mathematical operation

# %% [markdown]
# <a name="subsection3.1"></a>
#
# ## Exercise 3: Basic Math Operations
#
# In this exercise, you will practice performing basic mathematical operations using integers in Python.
#
# ### Instructions
#
# 1. Define two variables with **integer values** (preferably non-zero).
#    For example: `num1 = 2026` and `num2 = 12`.
#
# 2. Perform the following operations using the two variables:
#    - Addition
#    - Subtraction
#    - Multiplication
#    - Division
#
# 3. Use the `print()` function to display the result of each operation. You can print them all on one line or each on a **new line**.
#
# ---
#
# ### Hint
# Python follows the standard order of operations, and division (`/`) always returns a decimal (float) value.

# %%
# write your code here

# %% [markdown]
# <a name = "subsection3.2"></a>
# **Exercise 4**
#
# * Write a script that asks the user for the radius of a circle (use `input()` function).
# * Convert the input to a float (since `input()` returns a string).
# * Calculate and print the area of the circle (use this formula: area = 3.14 * radius * radius or area = 3.14 * radius**2):
#
# $$
# \text{area} = \pi r^2
# $$
#
#
#   * examples:
#
#       https://www.includehelp.com/python/read-input-as-a-float.aspx
#
#       https://www.digitalocean.com/community/tutorials/python-convert-string-to-float

# %%
# write your code here

# %% [markdown]
# <a name = "subsection3.3"></a>
# **Exercise 5: Simple Math Operation**
#
# In this exercise, you will calculate the **total time you spend commuting to school or work in one year**.
#
# ### Instructions
#
# 1. Define a variable called `t_day` and assign your **daily commute time in minutes** to it.
#    This value can be a **float**.
#
# 2. Define a variable called `n_days` and assign the **number of days per week** you commute to school or work.
#    This value should be an **integer**.
#
# 3. Define a variable called `n_weeks` and assign the **number of weeks per year** you commute to school or work.
#    This value should be an **integer**.
#
# 4. Calculate the **total commute time in minutes for one year** and assign it to a variable called `my_commute_time`.
#
# 5. Round `my_commute_time` to **two decimal places** using the `round()` function.
#    Learn more about the `round()` function here:
#    https://www.w3schools.com/python/ref_func_round.asp
#
# 6. Print the result using a complete sentence.
#    Example output:
#    > My commute time in a year is 8765.00 minutes.
#
# 7. Add an appropriate **comment** for each line of your code explaining what it does.

# %%
# write your code here

# %% [markdown]
# <a name = "section4"></a>
# **4. How to Submit the Assignment**
#
# Once you have finished writing your code, follow the steps below to submit your assignment.
#
# ### Step 1: Run the Entire Notebook
# - Run all code cells to make sure your notebook works correctly and displays all results.
# - To do this, go to the **Runtime** tab and click **Run all**.
#
# ### Step 2: Check Your Work
# - Make sure you followed all instructions.
# - Confirm that you answered all questions and that the outputs look correct.
#
# ### Step 3: Rename and Save the Notebook
# - Click on the notebook name at the **top left** of the page.
# - The default name is:
#   `ABT182_hw1.ipynb`
# - Rename the file by replacing **ABT182** with your own name.
#
#   **Example:**
#   `ali_moghimi_hw1.ipynb`
#
# - Save the notebook after renaming.
#
# ### Step 4: Create PDF Version
# - Creating a PDF version of your notebook is **required**.
# - To create a PDF:
#   1. Go to the **File** tab (top left).
#   2. Select **Print** (or press `Ctrl + P` / `Cmd + P`).
#   3. In the print window, change the **Destination** to **Save as PDF** or **Adobe PDF**.
#   4. Click **Print** to save the PDF file.
# - Alternatively: **File** → **Download** → **Download .pdf**
#
# ### Step 5: Submit Both Files to Canvas
# - **Upload BOTH files** to the **Canvas page** for this assignment:
#   1. The renamed notebook file (`.ipynb` file) - **REQUIRED**
#   2. The PDF file (`.pdf` file) - **REQUIRED**
# - Make sure both files are uploaded before submitting.
#
# ### Use of Generative AI Tools (GenAI Policy)
# - This course **discourages the use of generative AI tools** (such as ChatGPT) for completing assignments, as the goal is for you to develop your own coding skills.
# - If you **do choose to use a generative AI tool**, you must **clearly disclose** this in your notebook.
# - In your disclosure, briefly explain:
#   - which tool you used, and
#   - how you used it (e.g., debugging, understanding error messages, or clarifying concepts).
# - Failure to disclose the use of generative AI tools may be considered a violation of course academic integrity policies.

# %% [markdown]
# <a name = "section5"></a>
# **5. Resources to learn Python**
#
# * [Python Tutorial](https://www.w3schools.com/python/)
# * [Python Tutorial for Beginners](https://edabit.com/tutorial/python)
