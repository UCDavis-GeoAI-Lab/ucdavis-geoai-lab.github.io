# %% [markdown]
# <font color="green"><h2> **Welcome to ABT/HYD 182**
#
#
#  ## **Lab 4**: Python Functions
#
# ### **Due Date: Feb 5 | 11:59 PM**
# ------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------
# Learning objectives
# ---------------------------------------------
# - We will learn and practice how to develop functions and how to plot graphs in Python.
#
#
# Recourses:
# - [Python functions](https://www.w3schools.com/python/python_functions.asp)
# - [Matplotlib for visualization](https://matplotlib.org/)
# - [Matplotlib examples](https://matplotlib.org/stable/plot_types/index.html)

# %% [markdown]
# -------------------------------------------------------
# <a name = "section1"></a>
# **Exercise 1**
# ------------------------------------------------------
#
# * Create a function that converts Fahrenheit to Celsius temperature.
#
#     * The input is a temperature in Fahrenhiet.
#     * Subtract 32 from the input number and multiply by (5/9).
#     * Print the output in the terminal and return it as the function output.
#     * Once you write your function, call the function to convert 100 F to C.
#     * Add a documentation strings () using triple quotes. The docstring should explain what the function does. This docstring will be accessible through Python's built-in help system. For instance, if you call help(name_of_your_function) in a Python interpreter, it will display this docstring, providing valuable information about the function's purpose and usage.
#
# Resources:
# - [Python Docstrings](https://www.geeksforgeeks.org/python-docstrings/)

# %%
# as an example, we provide the docstring here. Please feel free to revise.

def fahr2cels(temperature):
  '''
  Convert Fahrenheit to Celsius temperature.

  This function takes a temperature in Fahrenheit and converts it to Celsius.
  The function prints the result in the terminal and returns a temp in Celsius.

  temp_c = (temp_f - 32) * 5 / 9

  parameters:
        - temp in F (float)

  returns:
        - temp in C (float)

  '''
  temp_c = (temperature - 32) * 5 / 9
  print(f"{temperature} Fahrenheit is {temp_c:.2f} Celsius")
  return temp_c

# %%
# let's check the docstrings
help(fahr2cels)

# %%
# let's call your function now
cels = fahr2cels(100)
print(f"The function output is {round(cels, 2)}.")

# %% [markdown]
# ------------------------------
# <a name = "section2"></a>
# **Exercise 2**
# ------------------------------
#
#   * Create a function odd_even() that creates a list of even and odd numbers from an input list
#
#     *   create an empty list for odd and even lists.
#     *   loop through the input list.
#     *   check if the number is odd or even.
#     *   if the number is odd, add (use 'append') the number to the odd list.
#     *   if the number is even, add (use 'append') the number to the even list.
#     *   return both lists.
#     *   check your function with the following list of numbers and print the output in the terminal.
#     *   add docstrings.
#
# ```
# input_list = [65, 21, 42, 84, 108, 32, 0, 7, 2547, 329]
# ```
#
# * expected outcome
# ```
# list of even number:  [42, 84, 108, 32, 0]
# list of odd number:  [65, 21, 7, 2547, 329]
# ```

# %%
def odd_even(input_list):
    '''
    Creates a list of even and odd numbers from an input list.
    Parameters:
        input_list: A list of numbers
    Returns:
        even_list: A list of even numbers
        odd_list: A list of odd numbers
    '''
    even_list = []
    odd_list = []
    for num in input_list:
        if num % 2 == 0:
            even_list.append(num)
        else:
            odd_list.append(num)
    return even_list, odd_list

# %%
def odd_even(input_list):
    '''
    Creates a list of even and odd numbers from an input list.
    Parameters:
        input_list: A list of numbers
    Returns:
        even_list: A list of even numbers
        odd_list: A list of odd numbers
    '''
    even_list = []
    odd_list = []
    for num in input_list:
        if num % 2 == 0:
            even_list.append(num)
        else:
            odd_list.append(num)
    return even_list, odd_list

# %% [markdown]
# --------------------------------------------
# <a name = "section3"></a>
# **Exercise 3**
# --------------------------------------------
#
# Write a Python function that converts latitude and longitude from degrees, minutes, seconds format to decimal degrees format. You may name your function `dms_to_dd()`
# - add docstrings.
# - call your function to convert the following sample data.
#
# Resources:
# - [Converting Degrees, Minutes, and Seconds to Decimal Degrees](https://study.com/skill/learn/how-to-convert-degrees-minutes-seconds-to-decimal-degrees-explanation.html)
# - [Compare your results with this convertor](https://www.fcc.gov/media/radio/dms-decimal)
#
# ```
# # call your function to convert the 36 degree, 7 minutes, and 30 seconds.
# dms = (36, 7, 30)
# ```

# %%
def dms_to_dd(degrees, minutes, seconds):
    '''
    Convert latitude/longitude from degrees, minutes, seconds to decimal degrees.
    Parameters:
        degrees: Integer degrees
        minutes: Integer minutes
        seconds: Integer or float seconds
    Returns:
        decimal_degrees: Float value in decimal degrees format
    '''
    decimal_degrees = degrees + (minutes / 60.0) + (seconds / 3600.0)
    return decimal_degrees

# %%
def dms_to_dd(degrees, minutes, seconds):
    '''
    Convert latitude/longitude from degrees, minutes, seconds to decimal degrees.
    Parameters:
        degrees: Integer degrees
        minutes: Integer minutes
        seconds: Integer or float seconds
    Returns:
        decimal_degrees: Float value in decimal degrees format
    '''
    decimal_degrees = degrees + (minutes / 60.0) + (seconds / 3600.0)
    return decimal_degrees

# %% [markdown]
# --------------------
# <a name = "section4"></a>
# **Exercise 4**
# -------------------
#
# GIS Data Filter
#
# Write a Python function that takes
#
# - a dictionary representing GIS data (each dictionary has latitude, longitude, and maybe with some attributes) and
# - a bounding box (The bounding box is defined by its southwest (lower left) and northeast (upper right) corners.)
#
#     and returns
#
# - a list of points in dictionary format that fall within the given bounding box.
#
# Part A: Check your code with the following data.
# ```
# # a dictionary containing 6 points
# point_dic = {
#             'p1': (40.7189, -73.9981),  # Latitude, Longitude
#             'p2': (40.7292, -73.9904),  # Latitude, Longitude
#             'p3': (40.6890, -73.9977),  # Latitude, Longitude
#             'p4': (40.7065, -73.9795),  # Latitude, Longitude
#             'p5': (40.6580, -74.0532),  # Latitude, Longitude
#             "p6":  (40.7128, -74.0060)  # Latitude, Longitude
#             }
#
# bbox = (40.7000, -74.0200, 40.7300, -73.9900)
#
# bbox_southwest: (40.7000, -74.0200) # Lower left corner
# bbox_northeast: (40.7300, -73.9900) # Upper right corner
# ```
#
# Expected outcome that should be printed in the terminal:
# ```
# {'p1': (40.7189, -73.9981), 'p2': (40.7292, -73.9904), 'p6': (40.7128, -74.006)}
# ```
#
#
# Part B: Check your code with the following data as well. This exercise demonstrates once you create a function you can call it and pass various data/parameters. This is the beauty of defining a function in programming (making tasks automated).
#
# ```
# new_point_dict = {
#     'p1': (40.7201, -73.9993),  # Latitude, Longitude
#     'p2': (40.7274, -73.9928),  # Latitude, Longitude
#     'p3': (40.6905, -73.9969),  # Latitude, Longitude
#     'p4': (40.7050, -73.9850),  # Latitude, Longitude
#     'p5': (40.6605, -74.0568),  # Latitude, Longitude
#     'p6': (40.7152, -74.0115)   # Latitude, Longitude
# }
#
# # Defining a bounding box
# bbox = (40.7020, -74.0150, 40.7290, -73.9850)
#
# ```

# %%
def filter_points_in_bbox(point_dict, bbox):
    '''
    Filter points that fall within a bounding box.
    Parameters:
        point_dict: Dictionary with point IDs as keys and (lat, lon) tuples as values
        bbox: Tuple (southwest_lat, southwest_lon, northeast_lat, northeast_lon)
    Returns:
        Dictionary of points within the bounding box
    '''
    southwest_lat, southwest_lon, northeast_lat, northeast_lon = bbox
    filtered_points = {}
    for point_id, (lat, lon) in point_dict.items():
        if (southwest_lat <= lat <= northeast_lat and 
            southwest_lon <= lon <= northeast_lon):
            filtered_points[point_id] = (lat, lon)
    return filtered_points

# %%
def filter_points_in_bbox(point_dict, bbox):
    '''
    Filter points that fall within a bounding box.
    Parameters:
        point_dict: Dictionary with point IDs as keys and (lat, lon) tuples as values
        bbox: Tuple (southwest_lat, southwest_lon, northeast_lat, northeast_lon)
    Returns:
        Dictionary of points within the bounding box
    '''
    southwest_lat, southwest_lon, northeast_lat, northeast_lon = bbox
    filtered_points = {}
    for point_id, (lat, lon) in point_dict.items():
        if (southwest_lat <= lat <= northeast_lat and 
            southwest_lon <= lon <= northeast_lon):
            filtered_points[point_id] = (lat, lon)
    return filtered_points

# %%
def filter_points_in_bbox(point_dict, bbox):
    '''
    Filter points that fall within a bounding box.
    Parameters:
        point_dict: Dictionary with point IDs as keys and (lat, lon) tuples as values
        bbox: Tuple (southwest_lat, southwest_lon, northeast_lat, northeast_lon)
    Returns:
        Dictionary of points within the bounding box
    '''
    southwest_lat, southwest_lon, northeast_lat, northeast_lon = bbox
    filtered_points = {}
    for point_id, (lat, lon) in point_dict.items():
        if (southwest_lat <= lat <= northeast_lat and 
            southwest_lon <= lon <= northeast_lon):
            filtered_points[point_id] = (lat, lon)
    return filtered_points

# %% [markdown]
# ------------------
# <a name = "section5"></a>
# **Exercise 5**
# ----------------
#
# - Given a NumPy array representing yearly average temperatures for the last 24 years from 2000 to 2024, write a function that returns the years (e.g., 2021) with temperature anomalies. In this case, an anomaly is defined as a temperature that is more than **two** standard deviations away from the mean.
# - The function should return the years with temperature anomalies and the corresponding temperature as a dictionary. Print the output of the function in the terminal.
#
# - Hint: once you find the anomaly years and their temperature, you can use `zip()`,
# ```output = dict(zip(anomaly_years, anomaly_values))```, and return the zipped output (which will be a dictionary).
#
#
#
# ```
# # years from 2000 to 2024
# years = np.arange(2000, 2025)
#
# # temp data for 24 years
# temperatures = np.array([28.82, 22.00, 24.89, 31.20, 29.34, 10.11, 24.75, 19.24, 19.48, 22.05, 20.72, 27.27, 23.81, 15.00, 22.22, 21.67, 27.47, 18.97, 35.00, 15.73, 38.00, 23.27, 24.32, 16.29])  # Sample data
# ```
#
# - Expected outcome
# ```
# {2005: 10.11, 2020: 38.0}
# ```

# %%
import numpy as np

def find_temperature_anomalies(years, temperatures):
    '''
    Find years with temperature anomalies (more than 2 standard deviations from mean).
    
    Parameters:
        years: Array of years
        temperatures: Array of temperatures
    
    Returns:
        Dictionary with anomaly years as keys and temperatures as values
    '''
    mean_temp = np.mean(temperatures)
    std_temp = np.std(temperatures)
    
    # Find anomalies (more than 2 std away from mean)
    threshold = 2 * std_temp
    anomaly_indices = np.where(np.abs(temperatures - mean_temp) > threshold)[0]
    
    anomaly_years = years[anomaly_indices]
    anomaly_values = temperatures[anomaly_indices]
    
    # Create dictionary using zip
    output = dict(zip(anomaly_years, anomaly_values))
    
    return output

# %%
# Using the previously created temperatures array
years = np.arange(2000, 2025)

temperatures = np.array([28.82, 22.00, 24.89, 31.20, 29.34, 10.11, 24.75, 19.24, 19.48, 22.05, 20.72, 27.27, 23.81, 15.00, 22.22, 21.67, 27.47, 18.97, 35.00, 15.73, 38.00, 23.27, 24.32, 16.29])  # Sample data

# Call the function and print the output
anomalies = find_temperature_anomalies(years, temperatures)
print(anomalies)

# %% [markdown]
# ------
# <a name = "section6"></a>
# **Exercise 6**
# ------
#
# Basic Line Plot
#  - Write a function plot_basic_line that takes the following arguments and plots a line graph in the requested format.
#     - two lists, x and y
#     - a color with default value of 'red'
#     - line style with default value of '-' (solid line style)
#     - line width with default value of 2
#     - a string that specify the title of the plot
#
#  - Call your function in a loop to plot the same graph but with various colors, `colors = ["red", "green", "blue"]`
#  - The title of each plot should be the name of the name of the color passed to the function. e.g., the title of the first graph should be `red`.
#  - Change at least one of the line width or line style argument to a value different than the default value.
#
#  - hint: In Python, when defining a function with both default (optional), in this exercise color, and non-default (mandatory) arguments, in this exercise title, the non-default arguments must come first among the arguments of the function, followed by the default arguments. This is a requirement in Python's function definition syntax to avoid ambiguity during function calls.
#
#  Resources:
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
import matplotlib.pyplot as plt

def plot_basic_line(x, y, title, color='red', linestyle='-', linewidth=2):
    '''
    Plot a basic line graph.
    
    Parameters:
        x: List of x values
        y: List of y values
        title: String title for the plot
        color: Line color (default: 'red')
        linestyle: Line style (default: '-')
        linewidth: Line width (default: 2)
    '''
    plt.figure(figsize=(8, 6))
    plt.plot(x, y, color=color, linestyle=linestyle, linewidth=linewidth)
    plt.title(title)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.grid(True)
    plt.show()

# Test and call the function
x = [1, 2, 3, 4, 5, 6]
y = [1, 3, 9, 16, 10, 12]

colors = ["red", "green", "blue"]

# Call function in a loop with different colors
for color in colors:
    plot_basic_line(x, y, title=color, color=color, linestyle='--', linewidth=3)

# %%
# Test and call the function
x = [1, 2, 3, 4, 5, 6]
y = [1, 3, 9, 16, 10, 12]

colors = ["red", "green", "blue"]

# %% [markdown]
# -------
# <a name = "section7"></a>
# **Exercise 7**
# -------
#
# **Customized Bar Plot**
#
# - Write a function plot_custom_bar that takes a dictionary where the dictionary keys are categories (in this example, name of cities) and values are numbers (in this example, number of EV charging stations). Plot a bar graph where bars are colored based on the value (e.g., assign red color to values greater than 50, green color to the rest of values).
# - Run your function for the number of EV charging station for 10 cities in CA.
# ```
# cities = ['Los Angeles', 'San Francisco', 'San Diego', 'Sacramento', 'Fresno', 'San Jose', 'Oakland', 'Long Beach', 'Bakersfield', 'Anaheim']
# n_station = [70, 85, 50, 32, 10, 62, 31, 14, 9, 17]
# ```
#
# **NOTE**
#
# - the input data are `list`, you should first find a way to make a dictionary. Hint: use `zip()`.
# - the name of the cities may overlap (fall on the top of each other) on the x-axis. To prevent this and make it more readable, use `plt.xticks(rotation=XX).`, assign a good number to `XX`, which will be a degree to rotate the text with respect to the x axis.
#
# ** Bonus (extra 5 credits)**
# - On your bar plot, draw a horizontal black dashed line at 50 (which is our threshold in the example).
#
#
#
# ```expected output```
#
#
# ![img](lab_4_bar.png)

# %%
import matplotlib.pyplot as plt
def plot_custom_bar(data_dict):
    '''
    Plot a bar graph with colors based on values.
    Parameters:
        data_dict: Dictionary with categories as keys and numbers as values
    '''
    categories = list(data_dict.keys())
    values = list(data_dict.values())
    # Assign colors: red for values > 50, green otherwise
    colors = ['red' if val > 50 else 'green' for val in values]
    plt.figure(figsize=(10, 6))
    plt.bar(categories, values, color=colors)
    plt.title('Custom Bar Plot')
    plt.xlabel('Categories')
    plt.ylabel('Values')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
# call your function
cities = ['Los Angeles', 'San Francisco', 'San Diego', 'Sacramento', 'Fresno', 'San Jose', 'Oakland', 'Long Beach', 'Bakersfield', 'Anaheim']
n_station = [70, 85, 50, 32, 10, 62, 31, 14, 9, 17]
data = dict(zip(cities, n_station))

# %% [markdown]
# ----
# <a name = "section8"></a>
# **Exercise 8**
# ----
#
# Multiple Line Plot
# - Create a function plot_multiple_lines that takes a dictionary with lists as values and plots each list as a separate line in the graph.
#
# ```
# LA = [68, 70, 72, 71, 69, 68, 67]
# SF = [60, 61, 59, 58, 57, 56, 55]
# Sac = [65, 67, 69, 68, 66, 64, 63]
# data = dict(zip(["LA", "SF", "Sac"], [LA, SF, Sac]))
#
# plot_multiple_lines(data)  # this should plot three lines
# ```

# %%
import matplotlib.pyplot as plt
def plot_multiple_lines(data_dict):
    '''
    Plot multiple lines from a dictionary.
    Parameters:
        data_dict: Dictionary with labels as keys and lists of values as values
    '''
    plt.figure(figsize=(10, 6))
    for label, values in data_dict.items():
        plt.plot(values, label=label, marker='o')
    plt.title('Multiple Line Plot')
    plt.xlabel('Index')
    plt.ylabel('Values')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Test the function

LA = [68, 70, 72, 71, 69, 68, 67]
SF = [60, 61, 59, 58, 57, 56, 55]
Sac = [65, 67, 69, 68, 66, 64, 63]
data = dict(zip(["LA", "SF", "Sac"], [LA, SF, Sac]))

# %% [markdown]
# ----
# <a name = "section9"></a>
# **Exercise 9**
# ----
#
# Context: Imagine a team of geologists is conducting a survey of a 10x10 kilometer area in a mountainous region. They are interested in understanding the elevation variation across this area to plan for a new hiking trail. To simulate this scenario, we'll create a function that plots a 10x10 heatmap representing the elevation at various points in the region (please note the data is randomly generated).
#
# - Write a function plot_elevation_heatmap that plots a 10x10 grid of the given data. The values are represented as a heatmap (with vaious colors) using Matplotlib, giving an overview of the elevation changes in the area.
# - Use Matplotlib to plot this data as a heatmap, which will help visualize high and low elevation areas.
# - Add a color bar to indicate the elevation scale.
# - One of the function input (argument) should be a color map with a default value, such as `hot` or `viridis`.
# - We use NumPy to generate a random matrix to simulate elevation data. Please note since the data is randomly generated, it might vary from one person to another or from one run to the next run.
# ```
# elevation_data = np.random.rand(10, 10) * 1000  # Elevation range from 0 to 1000 meters.
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np
def plot_random_heatmap(data, cmap='viridis', title='Heatmap'):
    '''
    Plot a heatmap of elevation data.
    Parameters:
        data: 2D numpy array
        cmap: Colormap name (default: 'viridis')
        title: Plot title (default: 'Heatmap')
    '''
    plt.figure(figsize=(8, 6))
    plt.imshow(data, cmap=cmap, interpolation='nearest')
    plt.colorbar(label='Elevation (meters)')
    plt.title(title)
    plt.show()

# %%
# Test the function
elevation_data = np.random.rand(10, 10) * 1000  # Elevation range from 0 to 1000 meters.

plot_random_heatmap(elevation_data, cmap='hot')

plot_random_heatmap(elevation_data, cmap='copper')

# %% [markdown]
# ----
# <a name = "section10"></a>
# **Exercise 10**
# ----
#
# - Write a function plot_gis_scatter that creates a scatter plot representing the locations of different types of vegetation in a nature. The x and y coordinates represent the geographical location, the marker color represents the type of vegetation, and the marker size represents the density of vegetation at that location.
# - One of the input arguments of the function is color map with a default value, `cmap='viridis'`.
#
# Dataset: The dataset is a list of tuples, where each tuple contains:
#
# x-coordinate (longitude),
# y-coordinate (latitude),
# vegetation type (encoded as an integer: 1 for trees, 2 for bushes, 3 for grass),
# vegetation density (a float that will determine the size of the marker).
#
#
# Hints:
#
# - Use Matplotlib to create the scatter plot.
# - Differentiate the vegetation types by color.
# - Adjust the size of the markers based on vegetation density.

# %%
# data, a list of tuples: [(x, y, vegetation type, density)]
data = [
    (34.0219, -118.4814, 1, 120), # x, y, Trees, density
    (34.0220, -118.4820, 2, 310), # x, y, Bushes, density
    (34.0218, -118.4810, 3, 756), # x, y, Grass,  density
    (34.0221, -118.4815, 1, 512), # x, y, Trees, density
    (34.0217, -118.4818, 2, 250), # x, y, Bushes,  density
    (34.0216, -118.4812, 3, 150), # x, y, Grass, density
    (34.0215, -118.4821, 1, 900), # x, y, rees, density
    (34.0222, -118.4817, 2, 100), # x, y, Bushes, density
    (34.0223, -118.4813, 3, 550), # x, y, Grass, density
    (34.0214, -118.4816, 1, 385), # x, y, Trees, density
    (34.0224, -118.4822, 2, 700), # x, y, Bushes, density
    (34.0213, -118.4811, 3, 620), # x, y, Grass, density
    (34.0225, -118.4819, 1, 425), # x, y, Trees, density
    (34.0212, -118.4823, 2, 300), # x, y, Bushes, density
    (34.0226, -118.4814, 3, 150)  # x, y, Grass, density
]

# %%
import matplotlib.pyplot as plt

def plot_gis_scatter(data, cmap='viridis'):
    '''
    Create a scatter plot representing vegetation locations.
    
    Parameters:
        data: List of tuples (x, y, vegetation_type, density)
        cmap: Colormap name (default: 'viridis')
    '''
    x_coords = [point[0] for point in data]
    y_coords = [point[1] for point in data]
    vegetation_types = [point[2] for point in data]
    densities = [point[3] for point in data]
    
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(x_coords, y_coords, c=densities, s=densities, 
                         cmap=cmap, alpha=0.6, edgecolors='black')
    plt.colorbar(scatter, label='Density')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('GIS Scatter Plot - Vegetation Density')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# Test the function with the provided dataset
plot_gis_scatter(data)  # call the function with its default cmap

plot_gis_scatter(data, cmap = 'Reds')
